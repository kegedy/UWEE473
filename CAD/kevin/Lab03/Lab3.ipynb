# %%
# Imports
import os
import sys
import cmath
import math
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import sympy as sp
from sympy.utilities.lambdify import lambdify
from scipy import signal
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from matplotlib.ticker import LogLocator
import control

# %%
IN = pd.read_csv('/home/kegedy/Documents/EE473/Lab3/IN.csv')
OUT = pd.read_csv('/home/kegedy/Documents/EE473/Lab3/OUT.csv')
OUT_EX = pd.read_csv('/home/kegedy/Documents/EE473/Lab3/OUT_EX.csv')
VEX_PLUS = pd.read_csv('/home/kegedy/Documents/EE473/Lab3/VEX_PLUS.csv')
VSCHEM_PLUS = pd.read_csv('/home/kegedy/Documents/EE473/Lab3/VSCHEM_PLUS.csv')

# %%
fig, ax = plt.subplots(2,1,figsize=(12,12))

ax[0].set_title('Schematic and Post-Layout Waveforms')
ax[0].plot(IN['IN_X'],IN['IN_Y'],label='IN')
ax[0].plot(OUT['OUT_X'],OUT['OUT_Y'],label='OUT')
ax[0].plot(OUT_EX['OUT_EX_X'],OUT_EX['OUT_EX_Y'],label='OUT_EX')
ax[0].set_ylabel('Voltage [V]')
ax[0].set_xlim([12.35e-9,12.75e-9])
ax[0].ticklabel_format(axis="x", style="sci", scilimits=(-9,-9))
ax[0].grid(which='both', axis='both')
ax[0].legend()

ax[1].plot(VEX_PLUS['VEX_PLUS_X'],VEX_PLUS['VEX_PLUS_Y'],label='VEX_PLUS',color='tab:red')
ax[1].plot(VSCHEM_PLUS['VSCHEM_PLUS_X'],VSCHEM_PLUS['VSCHEM_PLUS_Y'],label='VSCHEM_PLUS',color='tab:purple')
ax[1].set_xlim([12.35e-9,12.75e-9])
ax[1].set_ylabel('Current [A]')
ax[1].set_xlabel('Time [s]')
ax[1].grid(which='both', axis='both')
ax[1].ticklabel_format(axis="x", style="sci", scilimits=(-9,-9))
ax[1].ticklabel_format(axis="y", style="sci", scilimits=(-6,-6))
ax[1].legend()
plt.show();
